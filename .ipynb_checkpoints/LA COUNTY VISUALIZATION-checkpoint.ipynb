# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
la = pd.read_csv("LA_County_Covid19_cases_deaths_date_table.csv")
la.head()
# Out:
#    Unnamed: 0    date_use  total_cases  new_case  avg_cases  total_deaths  \
# 0           1  2020-12-29       718510       278     7077.0          9520
# 1           2  2020-12-28       718232      6299     9469.0          9520
# 2           3  2020-12-27       711933      5390    10857.0          9513
# 3           4  2020-12-26       706543     12417    10898.0          9476
# 4           5  2020-12-25       694126      2011    10751.0          9411
#
#    new_deaths  avg_deaths
# 0           0        40.0
# 1           7        54.0
# 2          37        68.0
# 3          65        77.0
# 4          45        81.0

# %%
la = la[["date_use", "total_cases","new_case","total_deaths","new_deaths"]]
la["date_use"] = pd.to_datetime(la["date_use"])
la.head()
la.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_use      304 non-null    datetime64[ns]
#  1   total_cases   304 non-null    int64
#  2   new_case      304 non-null    int64
#  3   total_deaths  304 non-null    int64
#  4   new_deaths    304 non-null    int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 12.0 KB

# %%
# ax = plt.gca()
la.plot(kind='line',x='date_use',y='total_cases',figsize=(50,20),label="total cases")
# la_plot.set_xticklabels(la["date_use"], rotation=45, ha = "right")
# plt.xticks(la["date_use"])
la.plot(kind='bar',x="date_use", y="new_case",label ="daily new cases")
# plt.legend(loc='upper right')
plt.show()
